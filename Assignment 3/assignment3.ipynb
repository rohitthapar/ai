# %%
import copy
from queue import PriorityQueue as pq
from math import sqrt

# Euclidean
closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in closedState:
            countTest=euclideanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in closedState:
            countTest=euclideanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in closedState:
            countTest=euclideanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in closedState:
            countTest=euclideanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

# def countHeuristicFunction(currentState):
#     count=0
#     for i in range(3):
#         for j in range(3):
#             if currentState[i][j]!=goalState[i][j]:
#                 count+=1
    
#     return count

def euclideanDistance(goalState, currentState):
    blockValue=0
    totalDist=0
    while blockValue<9:
        for i in range(3):
            for j in range(3):
                if goalState[i][j]==blockValue:
                    rg,cg=i,j
                if currentState[i][j]==blockValue:
                    rc,cc=i,j
        blockValue+=1
        totalDist=sqrt(pow(rg-rc,2)+pow(cg-cc,2))
    
    return totalDist
        

def search():
    countTest=euclideanDistance(goalState,initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    flag=1
    while flag:
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
#             print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            print(x[0])
            closedState.append(x[1])
            if x[1]==goalState:
                print(closedState)
    
    
    
search()

# %%
import copy
from queue import PriorityQueue as pq
from math import sqrt
# Manhattan
openState=[]
closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in openState and child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in openState and child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in openState and child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in openState and child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def manhattanDistance(goalState, currentState):
    blockValue=0
    totalDist=0
    while blockValue<9:
        for i in range(3):
            for j in range(3):
                if goalState[i][j]==blockValue:
                    rg,cg=i,j
                if currentState[i][j]==blockValue:
                    rc,cc=i,j
        blockValue+=1
        totalDist=abs(rg-rc)+abs(cg-cc)
    
    return totalDist
        

def search():
    countTest=manhattanDistance(goalState,initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    flag=1
    while flag:
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
#             print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            closedState.append(x[1])
            if x[1]==goalState:
                print(closedState)
                print(len(closedState))
    
    
    
search()

# %%
import copy
from queue import PriorityQueue as pq
from math import sqrt
# Minkowski
openState=[]
closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in openState and child not in closedState:
            countTest=minkowskiDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in openState and child not in closedState:
            countTest=minkowskiDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in openState and child not in closedState:
            countTest=minkowskiDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in openState and child not in closedState:
            countTest=minkowskiDistance(goalState,child)
            bfsState.put((countTest, child))
            openState.append(child)
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def minkowskiDistance(goalState, currentState):
    blockValue=0
    totalDist=0
    while blockValue<9:
        for i in range(3):
            for j in range(3):
                if goalState[i][j]==blockValue:
                    rg,cg=i,j
                if currentState[i][j]==blockValue:
                    rc,cc=i,j
        blockValue+=1
#         print(rg,cg)
#         print(rc,cc)
        totalDist=abs(rg-rc)+abs(cg-cc)
    
    return totalDist
        

def search():
    countTest=minkowskiDistance(goalState,initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    flag=1
    while flag:
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
#             print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            closedState.append(x[1])
            if x[1]==goalState:
                print(closedState)
                print(len(closedState))
    
    
    
search()

# %%
import copy
from queue import PriorityQueue as pq
#Best First Search Misplaced Tiles
closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0: 
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def countHeuristicFunction(currentState):
    count=0
    for i in range(3):
        for j in range(3):
            if currentState[i][j]!=goalState[i][j]:
                count+=1
    
    return count


def search():
    countTest=countHeuristicFunction(initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    flag=1
    while flag:
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
            print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            closedState.append(x[1])
            if x[1]==goalState:
                flag=0
                print(closedState)
                print(len(closedState))
    
    
    
search()
# Out:
# [[[0, 2, 3], [1, 8, 4], [7, 6, 5]], [[1, 2, 3], [0, 8, 4], [7, 6, 5]], [[1, 2, 3], [8, 0, 4], [7, 6, 5]]]
# 3

# %%
#Simple Hill Climbing

import copy
from queue import PriorityQueue as pq

minCount=100

closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            if countTest < minCount:
                bfsState.put((countTest, child))
                return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            if countTest < minCount:
                bfsState.put((countTest, child))
                return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            if countTest < minCount:
                bfsState.put((countTest, child))
                return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            if countTest < minCount:
                bfsState.put((countTest, child))
                return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def countHeuristicFunction(currentState):
    count=0
    for i in range(3):
        for j in range(3):
            if currentState[i][j]!=goalState[i][j]:
                count+=1
    
    return count


def search():
    countTest=countHeuristicFunction(initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    minCount=x[0]
    flag=1
    while flag:
        print(minCount)
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
            print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            minCount=x[0]
            closedState.append(x[1])
            if x[1]==goalState:
                flag=0
                print(closedState)
                print(len(closedState))
    
    
    
search()
# Out:
# 4
# 3
# 2
# [[[0, 2, 3], [1, 8, 4], [7, 6, 5]], [[1, 2, 3], [0, 8, 4], [7, 6, 5]], [[1, 2, 3], [8, 0, 4], [7, 6, 5]]]
# 3

# %%
#Steep Hill Climbing

import copy
from queue import PriorityQueue as pq

minCount=100
closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in closedState:
            countTest=countHeuristicFunction(child)
            bfsState.put((countTest, child))
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def countHeuristicFunction(currentState):
    count=0
    for i in range(3):
        for j in range(3):
            if currentState[i][j]!=goalState[i][j]:
                count+=1
    
    return count


def search():
    countTest=countHeuristicFunction(initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    minCount=x[0]
    flag=1
    while flag:
        print(minCount)
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
            print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            minCount=x[0]
            closedState.append(x[1])
            if x[1]==goalState:
                flag=0
                print(closedState)
                print(len(closedState))
    
    
    
search()
# Out:
# 4
# 3
# 2
# [[[0, 2, 3], [1, 8, 4], [7, 6, 5]], [[1, 2, 3], [0, 8, 4], [7, 6, 5]], [[1, 2, 3], [8, 0, 4], [7, 6, 5]]]
# 3

# %%
import copy
from queue import PriorityQueue as pq
from math import sqrt
# Best First Search Manhattan Distance


closedState=[]
bfsState=pq()
initialState=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goalState=[[1, 2, 3], [8, 0, 4], [7, 6, 5]]

# finding blank tile
def findBlankTile(currentState):
    for i in range(3):
        for j in range(3):
            if currentState[i][j]==0:
                r,c=i,j
                return r,c

#moving blank tile upwards
def moveUp(currentState, r, c):
    if r != 0:
        child = copy.deepcopy(currentState)
        child[r][c],child[r - 1][c] = (child[r - 1][c],0)
        if child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile downwards
def moveDown(currentState, r, c):
    if r != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r+1][c] = (child[r+1][c],0)
        if child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile leftwards
def moveLeft(currentState, r, c):
    if c != 0:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c-1] = (child[r][c-1],0)
        if child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None

#moving blank tile rightwards
def moveRight(currentState, r, c):
    if c != 2:
        child = copy.deepcopy(currentState)
        child[r][c], child[r][c+1] = (child[r][c+1],0)
        if child not in closedState:
            countTest=manhattanDistance(goalState,child)
            bfsState.put((countTest, child))
            
            return child
    return None


def isGoal(currentState,goalState):
    if currentState==goalState:
        return True
    return False

def manhattanDistance(goalState, currentState):
    blockValue=0
    totalDist=0
    while blockValue<9:
        for i in range(3):
            for j in range(3):
                if goalState[i][j]==blockValue:
                    rg,cg=i,j
                if currentState[i][j]==blockValue:
                    rc,cc=i,j
        blockValue+=1
        totalDist=abs(rg-rc)+abs(cg-cc)
    
    return totalDist
        

def search():
    countTest=manhattanDistance(goalState,initialState)
    bfsState.put((countTest, initialState))
    x=bfsState.get()
    flag=1
    while flag:
        currentState=x[1]
        if isGoal(currentState,goalState):
            flag = 0
#             print(len(closedState))
        else:
            r,c=findBlankTile(currentState)
            neighbour=[0]*4
            neighbour[0]=moveUp(currentState,r,c)
            neighbour[1]=moveDown(currentState,r,c)
            neighbour[2]=moveLeft(currentState,r,c)
            neighbour[3]=moveRight(currentState,r,c)
            x=bfsState.get()
            closedState.append(x[1])
            if x[1]==goalState:
                print(closedState)
                print(len(closedState))
    
    
    
search()
# Out:
# [[[0, 2, 3], [1, 8, 4], [7, 6, 5]], [[1, 2, 3], [0, 8, 4], [7, 6, 5]], [[1, 2, 3], [8, 0, 4], [7, 6, 5]]]
# 3
